# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %% [markdown]
# ### Resources
# https://www.w3schools.com/python/matplotlib_intro.asp
# https://matplotlib.org/stable/tutorials/index.html

# %% [markdown]
# ### Basics

# %%
xpoints = np.array([0,10])
ypoints = np.array([0,200])

# plot() draws line from point 1 to point 2 to point 3 ...

plt.plot(xpoints, ypoints)
plt.show()

# %%
xpoints = np.array([0,10,20])
ypoints = np.array([0,20,10])

plt.plot(xpoints,ypoints)
plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %% [markdown]
# ### Matplotlib structure

# %% [markdown]
# There's a procedural way to use matplotlib and an object oriented way.</br>
# The former uses plt.plot() and lets you add more stuff to it as you go but it only creates one plot in one figure.
# The latter can be used to divide the figure into a grid, with each portion getting a different plot

# %% [markdown]
# __Note__:
# * Figure: The entire area where graphs, charts, etc. get made
# * Axes: Used to define one plot. Not to be confused with axis (which are your conventional x,y,z axis)
